# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
import pandas as pd

# %%
from PIL import Image
data = Image.open('untl1.bmp')
arr = np.array(data)

# %%
plt.imshow(data)

# %%
size(arr)
# Out:
# 921600

# %%
arr.item(5)
# Out:
# 255

# %%
arr = np.array(data)
for i in range(307200):
    if arr.item(3*i)+arr.item(3*i+1)+arr.item(3*i+2)>=650:
        arr.itemset(3*i,255)
        arr.itemset(3*i+1,255)
        arr.itemset(3*i+2,255)
    else:
        arr.itemset(3*i,67)
        arr.itemset(3*i+1,149)
        arr.itemset(3*i+2,255)

# %%
plt.imshow(arr)

# %%
j = Image.fromarray(arr)
j.save("untl2.BMP")
